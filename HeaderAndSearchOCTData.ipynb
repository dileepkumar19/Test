# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
analytics = pd.read_csv('Report.csv')
analytics.head()
# Out:
#        Date          UserID HeaderAreaClicked HeaderItemClicked  \
# 0  1-Oct-20       a-dreddin               NaN               NaN
# 1  1-Oct-20       a-jemoran               NaN               NaN
# 2  1-Oct-20        a-kbilas               NaN               NaN
# 3  1-Oct-20  a-mkarimazondo               NaN               NaN
# 4  1-Oct-20        a-rennos               NaN               NaN
#
#   SearchResultClickedTitle
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
analytics.tail()
# Out:
#              Date     UserID HeaderAreaClicked HeaderItemClicked  \
# 1048570  8-Oct-20     pgutla               NaN               NaN
# 1048571  8-Oct-20     pgutla               NaN               NaN
# 1048572  8-Oct-20    pgutton               NaN               NaN
# 1048573  8-Oct-20     pguzik               NaN               NaN
# 1048574  8-Oct-20  pguzzardi               NaN               NaN
#
#                         SearchResultClickedTitle
# 1048570  CP3: Cohesive Pricing & Profit Planning
# 1048571             MySource - Audit & Assurance
# 1048572                                      NaN
# 1048573                                      NaN
# 1048574                                      NaN

# %%
analytics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   Date                      1048575 non-null  object
#  1   UserID                    1048575 non-null  object
#  2   HeaderAreaClicked         189544 non-null   object
#  3   HeaderItemClicked         189544 non-null   object
#  4   SearchResultClickedTitle  305273 non-null   object
# dtypes: object(5)
# memory usage: 40.0+ MB

# %%
analyticsNotNA = analytics.fillna(0)

# %%
analyticsNotNA
# Out:
#              Date          UserID HeaderAreaClicked HeaderItemClicked  \
# 0        1-Oct-20       a-dreddin                 0                 0
# 1        1-Oct-20       a-jemoran                 0                 0
# 2        1-Oct-20        a-kbilas                 0                 0
# 3        1-Oct-20  a-mkarimazondo                 0                 0
# 4        1-Oct-20        a-rennos                 0                 0
# ...           ...             ...               ...               ...
# 1048570  8-Oct-20          pgutla                 0                 0
# 1048571  8-Oct-20          pgutla                 0                 0
# 1048572  8-Oct-20         pgutton                 0                 0
# 1048573  8-Oct-20          pguzik                 0                 0
# 1048574  8-Oct-20       pguzzardi                 0                 0
#
#                         SearchResultClickedTitle
# 0                                              0
# ...

# %%
analyticsNotNA.loc[(analyticsNotNA.HeaderAreaClicked != 0), 'HeaderAreaClicked'] = 1
analyticsNotNA.loc[(analyticsNotNA.HeaderItemClicked != 0), 'HeaderItemClicked'] = 1
analyticsNotNA.loc[(analyticsNotNA.SearchResultClickedTitle != 0), 'SearchResultClickedTitle'] = 1

# %%
analyticsNotNA
# Out:
#              Date          UserID HeaderAreaClicked HeaderItemClicked  \
# 0        1-Oct-20       a-dreddin                 0                 0
# 1        1-Oct-20       a-jemoran                 0                 0
# 2        1-Oct-20        a-kbilas                 0                 0
# 3        1-Oct-20  a-mkarimazondo                 0                 0
# 4        1-Oct-20        a-rennos                 0                 0
# ...           ...             ...               ...               ...
# 1048570  8-Oct-20          pgutla                 0                 0
# 1048571  8-Oct-20          pgutla                 0                 0
# 1048572  8-Oct-20         pgutton                 0                 0
# 1048573  8-Oct-20          pguzik                 0                 0
# 1048574  8-Oct-20       pguzzardi                 0                 0
#
#         SearchResultClickedTitle
# 0                              0
# 1                              0
# ...

# %%
sns.barplot(x='Date', y='SearchResultClickedTitle', data=analyticsNotNA)
plt.rcParams['figure.figsize'] = [20, 15]

# %%
categories = ['HeaderAreaClicked','HeaderItemClicked','SearchResultClickedTitle']
