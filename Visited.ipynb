# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dta=pd.read_csv('data/Report20200901-20200930.csv', nrows=50000000,encoding='ISO-8859-1',parse_dates=['ï»¿"Date"'])
dta.tail()
# Out:
#          ï»¿"Date" User ID (v14) (evar14)    Service Line Local  \
# 4184363 2020-09-30           zzoomkawalla      Data Field Blank
# 4184364 2020-09-30                zzuberi  Internal Audit (RFA)
# 4184365 2020-09-30                zzuberi  Internal Audit (RFA)
# 4184366 2020-09-30                zzuberi  Internal Audit (RFA)
# 4184367 2020-09-30                zzuberi  Internal Audit (RFA)
#
#                        Service Area Local    Member Firm  Level Local  \
# 4184363                  Data Field Blank          India       Senior
# 4184364  Accounting and Internal Controls  United States  Associate 6
# 4184365  Accounting and Internal Controls  United States  Associate 6
# 4184366  Accounting and Internal Controls  United States  Associate 6
# 4184367  Accounting and Internal Controls  United States  Associate 6
#
#                       Function Local Deloitte Network Intranet (v51) (evar51)  \
# ...

# %%
import pandas as pd
from datetime import date
today = date.today()
d1 = today.strftime("%Y-%d-%m")
print("d1 =", d1)
date='2020-09-07'
name='dkleeger'
# Out:
# d1 = 2020-11-11

# %%
dfd2=dta.loc[dta['ï»¿"Date"'] == date]

# %%
dfd=dta.loc[dta['User ID (v14) (evar14)'] == name]

# %%
dfd=dfd2.loc[dfd2['User ID (v14) (evar14)'] == name]

# %%
pd.DataFrame(dfd['Header Item Clicked (v56) (evar56)'])
# Out:
#                        Header Item Clicked (v56) (evar56)
# 741557                                                NaN
# 741558                                                NaN
# 741559  Technology > How do I? > Access accounts / net...
# 741560                 Technology > Pages > Collaboration
# 741561               Technology > Pages > IT self service
# 741562                    Technology > Pages > Technology
# 741563                                        DeloitteNet
# 741564                                              Tools
# 741565                                               Work

# %%
pd.DataFrame(dfd['Search Result Clicked Title (v23) (evar23)'])
# Out:
#        Search Result Clicked Title (v23) (evar23)
# 741557                                        NaN
# 741558                                       Zoom
# 741559                                        NaN
# 741560                                        NaN
# 741561                                        NaN
# 741562                                        NaN
# 741563                                        NaN
# 741564                                        NaN
# 741565                                        NaN
