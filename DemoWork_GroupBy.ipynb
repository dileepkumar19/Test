# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Report20200501-20201030.csv', nrows=5000000,encoding='ISO-8859-1',parse_dates=['ï»¿"Date"'])

# %%
#df['ï»¿"Date"'] = pd.to_datetime(df['ï»¿"Date"'],errors = 'coerce')
df['ï»¿"Date"']=df['ï»¿"Date"'].dt.day_name()

# %%
df.describe().transpose()
# Out:
#                                                 count  unique  \
# ï»¿"Date"                                     5000000       7
# User ID (v14) (evar14)                        5000000  211335
# Service Line                                  4980854     108
# Service Line Local                            4980854     874
# Service Area                                  4980854      60
# Service Area Local                            4980854     502
# Member Firm                                   4980854      37
# Level Local                                   4980854     128
# Level                                         4980854      11
# Function Local                                4980854      47
# Function                                      4980854      11
# Deloitte Network Intranet (v51) (evar51)      5000000      43
# Header Area Clicked (v55) (evar55)             840665       6
# Header Item Clicked (v56) (evar56)             840665    3487
# Search Result Clicked Subtype (v59) (evar59)  1420754       5
# Search Result Clicked Title (v23) (evar23)    1468477   65948
#
#                                                                        top  \
# ï»¿"Date"                                                          Tuesday
# User ID (v14) (evar14)                                         cmilcinovic
# Service Line                                              Data Field Blank
# Service Line Local                                        Data Field Blank
# Service Area                                              Data Field Blank
# Service Area Local                                        Data Field Blank
# Member Firm                                                  United States
# Level Local                                                         Senior
# Level                                                               Senior
# Function Local                                                  Consulting
# Function                                                        Consulting
# Deloitte Network Intranet (v51) (evar51)                     United States
# Header Area Clicked (v55) (evar55)                            App Launcher
# Header Item Clicked (v56) (evar56)                                   SWIFT
# Search Result Clicked Subtype (v59) (evar59)                          Apps
# Search Result Clicked Title (v23) (evar23)    DTE: Deloitte Time & Expense
#
#                                                  freq
# ï»¿"Date"                                     1008420
# User ID (v14) (evar14)                            740
# Service Line                                  3041907
# Service Line Local                            1961714
# Service Area                                   833413
# Service Area Local                             825532
# Member Firm                                   3225007
# Level Local                                    992505
# Level                                         1250639
# Function Local                                1528917
# Function                                      1708500
# Deloitte Network Intranet (v51) (evar51)      3218492
# Header Area Clicked (v55) (evar55)             441123
# Header Item Clicked (v56) (evar56)             109684
# Search Result Clicked Subtype (v59) (evar59)   797634
# Search Result Clicked Title (v23) (evar23)     237250

# %%
name='aascione'
dfd=df.loc[df['User ID (v14) (evar14)'] == name]
dfd
# Out:
#          ï»¿"Date" User ID (v14) (evar14)  \
# 496         Friday               aascione
# 497         Friday               aascione
# 186111      Monday               aascione
# 186112      Monday               aascione
# 186113      Monday               aascione
# 369270     Tuesday               aascione
# 369271     Tuesday               aascione
# 535357   Wednesday               aascione
# 535358   Wednesday               aascione
# 694483    Thursday               aascione
# 694484    Thursday               aascione
# 1237899    Tuesday               aascione
# 1237900    Tuesday               aascione
# 1572648   Thursday               aascione
# 1572649   Thursday               aascione
# 1572650   Thursday               aascione
# 1742085     Friday               aascione
# 1742086     Friday               aascione
# 2155171    Tuesday               aascione
# 2155172    Tuesday               aascione
# 2878180  Supply Chain and Network Operations
# 3061281  Supply Chain and Network Operations
# 3674077  Supply Chain and Network Operations
# 3674078  Supply Chain and Network Operations
# 4012295  Supply Chain and Network Operations
# 4012296  Supply Chain and Network Operations
# 4346067  Supply Chain and Network Operations
# 4563945  Supply Chain and Network Operations
# 4563946  Supply Chain and Network Operations
# 4563947  Supply Chain and Network Operations
# 4746609  Supply Chain and Network Operations
# 4746610  Supply Chain and Network Operations
# 4746611  Supply Chain and Network Operations
#
#                                   Service Area      Service Area Local  \
# 496      Enterprise Technology and Performance  Enterprise Performance
# 497      Enterprise Technology and Performance  Enterprise Performance
# 186111   Enterprise Technology and Performance  Enterprise Performance
# 186112   Enterprise Technology and Performance  Enterprise Performance
# 186113   Enterprise Technology and Performance  Enterprise Performance
# 369270   Enterprise Technology and Performance  Enterprise Performance
# 369271   Enterprise Technology and Performance  Enterprise Performance
# 535357   Enterprise Technology and Performance  Enterprise Performance
# 535358   Enterprise Technology and Performance  Enterprise Performance
# 694483   Enterprise Technology and Performance  Enterprise Performance
# 694484   Enterprise Technology and Performance  Enterprise Performance
# 1237899  Enterprise Technology and Performance  Enterprise Performance
# 1237900  Enterprise Technology and Performance  Enterprise Performance
# 1572648  Enterprise Technology and Performance  Enterprise Performance
# 1572649  Enterprise Technology and Performance  Enterprise Performance
# 1572650  Enterprise Technology and Performance  Enterprise Performance
# 1742085  Enterprise Technology and Performance  Enterprise Performance
# 1742086  Enterprise Technology and Performance  Enterprise Performance
# 2155171  Enterprise Technology and Performance  Enterprise Performance
# 2155172  Enterprise Technology and Performance  Enterprise Performance
# 2155173  Enterprise Technology and Performance  Enterprise Performance
# 2480454  Enterprise Technology and Performance  Enterprise Performance
# 2480455  Enterprise Technology and Performance  Enterprise Performance
# 2878179  Enterprise Technology and Performance  Enterprise Performance
# 2878180  Enterprise Technology and Performance  Enterprise Performance
# 3061281  Enterprise Technology and Performance  Enterprise Performance
# 3674077  Enterprise Technology and Performance  Enterprise Performance
# 3674078  Enterprise Technology and Performance  Enterprise Performance
# 4012295  Enterprise Technology and Performance  Enterprise Performance
# 4012296  Enterprise Technology and Performance  Enterprise Performance
# 4346067  Enterprise Technology and Performance  Enterprise Performance
# 4563945  Enterprise Technology and Performance  Enterprise Performance
# 4563946  Enterprise Technology and Performance  Enterprise Performance
# 4563947  Enterprise Technology and Performance  Enterprise Performance
# 4746609  Enterprise Technology and Performance  Enterprise Performance
# 4746610  Enterprise Technology and Performance  Enterprise Performance
# 4746611  Enterprise Technology and Performance  Enterprise Performance
#
#            Member Firm Level Local   Level Function Local    Function  \
# 496      United States      Senior  Senior     Consulting  Consulting
# 497      United States      Senior  Senior     Consulting  Consulting
# 186111   United States      Senior  Senior     Consulting  Consulting
# 186112   United States      Senior  Senior     Consulting  Consulting
# 186113   United States      Senior  Senior     Consulting  Consulting
# 694483                                 NaN                                NaN
# 694484                                 NaN                                NaN
# 1237899                                NaN                                NaN
# 1237900                                NaN                                NaN
# 1572648                                NaN                                NaN
# 1572649                                NaN                                NaN
# 1572650                                NaN                                NaN
# 1742085                                NaN                                NaN
# 1742086                                NaN                                NaN
# 2155171                                NaN                                NaN
# 2155172                                NaN                                NaN
# 2155173                                NaN                                NaN
# 2480454                                NaN                                NaN
# 2480455                                NaN                                NaN
# 2878179                                NaN                                NaN
# 2878180                                NaN                                NaN
# 3061281                                NaN                                NaN
# 3674077                                NaN                                NaN
# 3674078                                NaN                                NaN
# 4012295                                NaN                                NaN
# 4012296                                NaN                                NaN
# 4346067                                NaN                                NaN
# 4563945                                NaN                                NaN
# 4563946                                NaN                                NaN
# 4563947                                NaN                                NaN
# 4746609                                NaN                                NaN
# 4746610                                NaN                                NaN
# 4746611                                NaN                                NaN
#
#         Search Result Clicked Subtype (v59) (evar59)  \
# 496                                              NaN
# 497                                            Pages
# 186111                                           NaN
# 186112                                          Apps
# 186113                                         Pages
# 369270                                           NaN
# 369271                                          Apps
# 535357                                           NaN
# 535358                                          Apps
# 694483                                           NaN
# 694484                                          Apps
# 1237899                                          NaN
# 1237900                                         Apps
# 1572648                                          NaN
# 1572649                                         Apps
# 1572650                                        Pages
# 1742085                                          NaN
# 1742086                                        Pages
# 2155171                                          NaN
# 2155172                                         Apps
# 2155173                                        Pages
# 2480454                                          NaN
# 2480455                                         Apps
# 2878179                                          NaN
# 2878180                                         Apps
# 3061281                                        Pages
# 3674077                                          NaN
# 3674078                                         Apps
# 4012295                                          NaN
# 4012296                                         Apps
# 4346067                                         Apps
# 4563945                                          NaN
# 4563946                                         Apps
# 4563947                                        Pages
# 4746609                                          NaN
# 4746610                                         Apps
# 4746611                                        Pages
#
#         Search Result Clicked Title (v23) (evar23)
# 496                                            NaN
# 497                           Web Template Central
# 186111                                         NaN
# 186112                  KX Deloitte People Network
# 186113                       TOD: Talent On Demand
# 369270                                         NaN
# 369271                                     STAFFIT
# 535357                                         NaN
# 535358                  KX Deloitte People Network
# 694483                                         NaN
# 694484                  KX Deloitte People Network
# 1237899                                        NaN
# 1237900                                    STAFFIT
# 1572648                                        NaN
# 1572649                                    STAFFIT
# 1572650                      TOD: Talent On Demand
# 1742085                                        NaN
# 1742086                            Poll Everywhere
# 2155171                                        NaN
# 2155172                                    STAFFIT
# 2155173                      TOD: Talent On Demand
# 2480454                                        NaN
# 2480455                                    STAFFIT
# 2878179                                        NaN
# 2878180                                    STAFFIT
# 3061281                      TOD: Talent On Demand
# 3674077                                        NaN
# 3674078                                    STAFFIT
# 4012295                                        NaN
# 4012296                                    STAFFIT
# 4346067                                    STAFFIT
# 4563945                                        NaN
# 4563946                                    STAFFIT
# 4563947                      TOD: Talent On Demand
# 4746609                                        NaN
# 4746610                                    STAFFIT
# 4746611                      TOD: Talent On Demand

# %%
Group=df.groupby(['ï»¿"Date"','Service Line Local','Service Area Local','Function Local','Member Firm','Level Local','Deloitte Network Intranet (v51) (evar51)'])
group2=Group['User ID (v14) (evar14)'] 
group3=Group['Header Area Clicked (v55) (evar55)']
group4=Group['Header Item Clicked (v56) (evar56)']
group5=Group['Search Result Clicked Subtype (v59) (evar59)']
group6=Group['Search Result Clicked Title (v23) (evar23)']

# %%
Output1=[]
Output2=[]
Output3=[]

for i,j in group2:
    Output1.append(list( dict.fromkeys(j.values)))
    
for i,j in group4:
    Output2.append(j.values)
    
for i,j in group6:
    Output3.append(j.values)

# %%
indexes=[]
for a in Output1:
    if name in a:
        indexes.append(a)
    
#indexes

# %%
pds=[]
for i in range(len(indexes)):
    pds.append(pd.DataFrame(Output1[Output1.index(indexes[i])]))

# %%
vee = pd.concat(pds)

# %%
vout=[]
for i in range(len(indexes)):
    vout.append(pd.DataFrame(Output2[Output1.index(indexes[i])],columns= ['Color']))
    vout.append(pd.DataFrame(Output3[Output1.index(indexes[i])],columns= ['Color']))


veeO=pd.concat(vout)
dups_color = veeO.pivot_table(index=['Color'], aggfunc='size').sort_values(ascending=False)
dups_color
# Out:
# Color
# STAFFIT                         680
# DTE: Deloitte Time & Expense    595
# TOD: Talent On Demand           278
# Talent On Demand                168
# KX Deloitte People Network      161
#                                ...
# My Personal Information           1
# Namrata Bhattacharjee             1
# Namrata Nande                     1
# Nancy Morton                      1
# 401(k) Plan                       1
# Length: 607, dtype: int64

# %%
#name='pdaniel'
L=df.loc[df['User ID (v14) (evar14)'] == name]
L1=pd.DataFrame(L[['Header Item Clicked (v56) (evar56)']],columns= ['Header Item Clicked (v56) (evar56)'])
L2=pd.DataFrame(L[['Search Result Clicked Title (v23) (evar23)']],columns= ['Search Result Clicked Title (v23) (evar23)'])

Li1=L1.rename(columns={"Header Item Clicked (v56) (evar56)": "Color"})
Li2=L2.rename(columns={"Search Result Clicked Title (v23) (evar23)": "Color"})

vee=pd.concat([Li1 ,Li2])
dups_color2 = vee.pivot_table(index=['Color'], aggfunc='size').sort_values(ascending=False)

# %%
dups_color2
# Out:
# Color
# STAFFIT                       11
# TOD: Talent On Demand          6
# KX Deloitte People Network     3
# Web Template Central           1
# Poll Everywhere                1
# dtype: int64

# %%
d1=pd.DataFrame(dups_color,columns= ['Count'])
d2=pd.DataFrame(dups_color2,columns= ['Count'])

# %%
pd.concat([d1,d2])
# Out:
#                               Count
# Color
# STAFFIT                         680
# DTE: Deloitte Time & Expense    595
# TOD: Talent On Demand           278
# Talent On Demand                168
# KX Deloitte People Network      161
# ...                             ...
# STAFFIT                          11
# TOD: Talent On Demand             6
# KX Deloitte People Network        3
# Web Template Central              1
# Poll Everywhere                   1
#
# [612 rows x 1 columns]
