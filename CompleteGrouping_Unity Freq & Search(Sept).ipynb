# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
df1=pd.read_csv('Report_user (3).csv',encoding='ISO-8859-1')
df1
# Out:
#         ï»¿"User ID (v14) (evar14)" Tenure (yrs)         Subregion  \
# 0                100robot.jupiter01          NaN               NaN
# 1                           a-adrar          NaN               NaN
# 2                            a-aneo          NaN               NaN
# 3                            a-aneo          NaN               NaN
# 4                  a-ashutoshkumar2          NaN               NaN
# ...                             ...          ...               ...
# 2532432                     zzuberi      6 to 10  Data Field Blank
# 2532433                     zzuberi      6 to 10  Data Field Blank
# 2532434                      zzwane  Less than 1  Data Field Blank
# 2532435                      zzwane  Less than 1  Data Field Blank
# 2532436                      zzwane  Less than 1  Data Field Blank
#
#              Service Line                      Service Area            Office  \
# 0                     NaN                               NaN               NaN
# 1                     NaN                               NaN               NaN
# 2                     NaN                               NaN               NaN
# 3                     NaN                               NaN               NaN
# 4                     NaN                               NaN               NaN
# ...                   ...                               ...               ...
# 2532432    Internal Audit  Accounting and Internal Controls  Data Field Blank
# 2532433    Internal Audit  Accounting and Internal Controls  Data Field Blank
# 2532434  Data Field Blank                     Human Capital  Data Field Blank
# 2532435  Data Field Blank                     Human Capital  Data Field Blank
# 2532436  Data Field Blank                     Human Capital  Data Field Blank
#
#            Member Firm   Level Local         Level  \
# 0                  NaN           NaN           NaN
# 1                  NaN           NaN           NaN
# 2                  NaN           NaN           NaN
# 3                  NaN           NaN           NaN
# 4                  NaN           NaN           NaN
# ...                ...           ...           ...
# 2532432  United States   Associate 6        Senior
# 2532433  United States   Associate 6        Senior
# 2532434         Africa  Junior Staff  Junior Staff
# 2532435         Africa  Junior Staff  Junior Staff
# 2532436         Africa  Junior Staff  Junior Staff
#
#                       Function Local  ... Header Area Clicked (v55) (evar55)  \
# 0                                NaN  ...                                NaN
# 1                                NaN  ...                                NaN
# 2                                NaN  ...                                NaN
# 3                                NaN  ...                                NaN
# 4                                NaN  ...                                NaN
# ...                              ...  ...                                ...
# 2532432  Risk and Financial Advisory  ...                                NaN
# 2532433  Risk and Financial Advisory  ...                                NaN
# 2532434                   Consulting  ...                                NaN
# 2532435                   Consulting  ...                                NaN
# 2532436                   Consulting  ...                                NaN
#
#         Header Item Clicked (v56) (evar56)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2532432                                NaN
# 2532433                                NaN
# 2532434                                NaN
# 2532435                                NaN
# 2532436                                NaN
#
#         Search Result Clicked Detail (v60) (evar60)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 2532432                                Result title
# 2532433                                Result title
# 2532434                                         NaN
# 2532435                                         NaN
# 2532436                                         NaN
#
#         Search Result Clicked Subtype (v59) (evar59)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 2532432                                        Pages
# 2532433                                        Pages
# 2532434                                          NaN
# 2532435                                          NaN
# 2532436                                          NaN
#
#         Search Result Clicked Title (v23) (evar23)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2532432                      TOD: Talent On Demand
# 2532433                      TOD: Talent On Demand
# 2532434                                        NaN
# 2532435                                        NaN
# 2532436                                        NaN
#
#         Search Result Clicked Type (v58) (evar58) Search Type (v25) (evar25)  \
# 0                                             NaN                        NaN
# 1                                             NaN                        NaN
# 2                                             NaN                        NaN
# 3                                             NaN                        NaN
# 4                                             NaN                        NaN
# ...                                           ...                        ...
# 2532432                       Instant Find Result               Instant Find
# 2532433                       Instant Find Result               Instant Find
# 2532434                                       NaN                        NaN
# 2532435                                       NaN                        NaN
# 2532436                                       NaN   Instant Find DIGS Search
#
#         Search Terms (v26) (evar26)        Capability  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 2532432            talent on demand  Data Field Blank
# 2532433                         TOD  Data Field Blank
# 2532434                         NaN  Data Field Blank
# 2532435                         NaN  Data Field Blank
# 2532436                         4pl  Data Field Blank
#
#                                    Breadcrumb (v9) (evar9)
# 0                Global > Clients & Industries > No Access
# 1        Deloitte Global & GFS home > Welcome to the DT...
# 2        Worldwide Technology > Products & Services eCa...
# 3        Worldwide Technology > Products & Services eCa...
# 4        Worldwide Technology > Products & Services eCa...
# ...                                                    ...
# 2532432                                                NaN
# 2532433                                                NaN
# 2532434                                               Home
# 2532435                    South Africa > UnityRedirection
# 2532436                                                NaN
#
# [2532437 rows x 22 columns]

# %%
import plotly.express as px
ds = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['ï»¿"User ID (v14) (evar14)"'].count().reset_index()
ds3 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Search Result Clicked Detail (v60) (evar60)'].count().reset_index()
ds2 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Header Item Clicked (v56) (evar56)'].count().reset_index()

# %%
ds.index = [x for x in range(1, len(ds.values)+1)]
ds.index.name = 'id'

ds2.index = [x for x in range(1, len(ds2.values)+1)]
ds2.index.name = 'id'

ds3.index = [x for x in range(1, len(ds3.values)+1)]
ds3.index.name = 'id'

# %%
dsO=pd.merge(ds, ds2, on='id')

# %%
dsO2=pd.merge(dsO,ds3,on='id')

# %%
features=['ï»¿"User ID (v14) (evar14)"','Header Item Clicked (v56) (evar56)','Search Result Clicked Detail (v60) (evar60)']

# %%
cc=dsO2[features]

# %%
gg=df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['ï»¿"User ID (v14) (evar14)"']

# %%
dd1= df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['ï»¿"User ID (v14) (evar14)"']
dd1.count().reset_index().count()
# Out:
# Service Line                   1050
# Service Area                   1050
# Function                       1050
# Member Firm                    1050
# ï»¿"User ID (v14) (evar14)"    1050
# dtype: int64

# %%
dd2=df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Header Item Clicked (v56) (evar56)']

# %%
#for i,j in dd1:
 #   print(j)

# %%
#for (i, j) in dd1:
  
 #  print('Column Contents : ', j.drop_duplicates() + "Count" , len(j))

# %%
#for (i, j) in dd1:
 #  print('Colunm Name : ',i[3])
  # print('Column Contents : ', j)

# %%
ds = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['ï»¿"User ID (v14) (evar14)"']

ds2 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Header Item Clicked (v56) (evar56)']
ds4 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Header Area Clicked (v55) (evar55)']

ds7 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Search Type (v25) (evar25)']
ds5 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Search Result Clicked Type (v58) (evar58)']
ds6 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Search Result Clicked Subtype (v59) (evar59)']
ds3 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Search Result Clicked Detail (v60) (evar60)']
ds9 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Search Result Clicked Title (v23) (evar23)']
ds8 = df1.groupby(['Service Line', 'Service Area', 'Function','Member Firm'])['Search Terms (v26) (evar26)']

# %%
Output1=[]
Output2=[]
Output3=[]
Output4=[]
Output5=[]
Output6=[]
Output7=[]
Output8=[]
Output9=[]

for i,j in ds:
    Output1.append(list( dict.fromkeys(j.values)))

for i,j in ds2:
    Output2.append(j.values)

for i,j in ds3:
    Output3.append(j.values)

for i,j in ds4:
    Output4.append(j.values)

for i,j in ds5:
    Output5.append(j.values)

for i,j in ds6:
    Output6.append(j.values)

for i,j in ds7:
    Output7.append(j.values)

for i,j in ds8:
    Output8.append(j.values)

for i,j in ds9:
    Output9.append(j.values)

# %%
dr=Output1

# %%
name='rperla'

# %%
indexes=[]
for a in Output1:
    if name in a:
        indexes.append(a)
    
#indexes

# %%
def countList(lst): 
    return sum(isinstance(i, list) for i in lst)

# %%
#print('Users',Output1[Output1.index(indexes[0])],'lenth: ',len(Output1[Output1.index(indexes[0])]))
pd.DataFrame(Output1[Output1.index(indexes[0])])
# Out:
#                0
# 0       aaansari
# 1       aalquity
# 2         aalvis
# 3     aamarshall
# 4        aamulya
# ...          ...
# 3444     zlahpai
# 3445       zluze
# 3446    zquinlan
# 3447  zumohammad
# 3448    zvitaliy
#
# [3449 rows x 1 columns]

# %%
#print('Header area Clicked ',Output2[Output1.index(indexes[0])],'Lenth: ',len(Output2[Output1.index(indexes[0])]))
pd.DataFrame(Output2[Output1.index(indexes[0])])
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 29540  NaN
# 29541  NaN
# 29542  NaN
# 29543  NaN
# 29544  NaN
#
# [29545 rows x 1 columns]

# %%
#print('Search Result Clicked',Output3[Output1.index(indexes[0])],'Lenth: ',len(Output3[Output1.index(indexes[0])]))
pd.DataFrame(Output3[Output1.index(indexes[0])])
# Out:
#                   0
# 0               NaN
# 1               NaN
# 2               NaN
# 3      Result title
# 4      Result title
# ...             ...
# 29540  Result title
# 29541  Result title
# 29542           NaN
# 29543           NaN
# 29544           NaN
#
# [29545 rows x 1 columns]

# %%
#print('Header area Clicked ',Output4[Output1.index(indexes[0])],'Lenth: ',len(Output4[Output1.index(indexes[0])]))
pd.DataFrame(Output4[Output1.index(indexes[0])])
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 29540  NaN
# 29541  NaN
# 29542  NaN
# 29543  NaN
# 29544  NaN
#
# [29545 rows x 1 columns]

# %%
#print('search result clicked Type',Output5[Output1.index(indexes[0])],'Lenth: ',len(Output5[Output1.index(indexes[0])]))
pd.DataFrame(Output5[Output1.index(indexes[0])])
# Out:
#                          0
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3      Instant Find Result
# 4      Instant Find Result
# ...                    ...
# 29540  Instant Find Result
# 29541  Instant Find Result
# 29542                  NaN
# 29543                  NaN
# 29544                  NaN
#
# [29545 rows x 1 columns]

# %%
#print('search result clicked SubType',Output6[Output1.index(indexes[0])],'Lenth: ',len(Output6[Output1.index(indexes[0])]))
pd.DataFrame(Output6[Output1.index(indexes[0])])
# Out:
#            0
# 0        NaN
# 1        NaN
# 2        NaN
# 3       Apps
# 4       Apps
# ...      ...
# 29540   Apps
# 29541  Pages
# 29542    NaN
# 29543    NaN
# 29544    NaN
#
# [29545 rows x 1 columns]

# %%
#print('Search Type',Output7[Output1.index(indexes[0])],'Lenth: ',len(Output7[Output1.index(indexes[0])]))
pd.DataFrame(Output7[Output1.index(indexes[0])])
# Out:
#                               0
# 0                           NaN
# 1                           NaN
# 2      Instant Find DIGS Search
# 3                  Instant Find
# 4                  Instant Find
# ...                         ...
# 29540              Instant Find
# 29541              Instant Find
# 29542                       NaN
# 29543                       NaN
# 29544                       NaN
#
# [29545 rows x 1 columns]

# %%
#print('Search Term',Output8[Output1.index(indexes[0])],'Lenth: ',len(Output8[Output1.index(indexes[0])]))
pd.DataFrame(Output8[Output1.index(indexes[0])])
# Out:
#                         0
# 0                     NaN
# 1                     NaN
# 2          talentondemand
# 3           software cata
# 4      software catalogue
# ...                   ...
# 29540                 DTE
# 29541                 TOD
# 29542                 NaN
# 29543                 NaN
# 29544                 NaN
#
# [29545 rows x 1 columns]

# %%
#print('Search result Clicked Title',Output9[Output1.index(indexes[0])],'Lenth: ',len(Output9[Output1.index(indexes[0])]))
pd.DataFrame(Output9[Output1.index(indexes[0])])
# Out:
#                                   0
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3         Deloitte Software Catalog
# 4         Deloitte Software Catalog
# ...                             ...
# 29540  DTE: Deloitte Time & Expense
# 29541         TOD: Talent On Demand
# 29542                           NaN
# 29543                           NaN
# 29544                           NaN
#
# [29545 rows x 1 columns]

# %%
#o1=df1.groupby(['ï»¿"User ID (v14) (evar14)"'])['Header Item Clicked (v56) (evar56)'].count().reset_index()

# %%
#o3=df1.groupby(['ï»¿"User ID (v14) (evar14)"'])['Search Result Clicked Title (v23) (evar23)'].count().reset_index()

# %%
#o1

# %%
#o2

# %%
Output2[Output1.index(indexes[0])]
# Out:
# array([nan, nan, nan, ..., nan, nan, nan], dtype=object)

# %%
ve=pd.DataFrame(Output2[Output1.index(indexes[0])],columns= ['Color'])

# %%
ve2=pd.DataFrame(Output9[Output1.index(indexes[0])],columns= ['Color'])

# %%
vee=pd.concat([ve ,ve2])

# %%
dups_color = vee.pivot_table(index=['Color'], aggfunc='size').sort_values(ascending=False)

# %%
dups_color
# Out:
# Color
# DTE: Deloitte Time & Expense    798
# TOD: Talent On Demand           632
# Talent On Demand                510
# My Technology                   489
# Tools                           434
#                                ...
# Julie Velayo                      1
# Julie Parkinson-Myers             1
# Joseph Harrison                   1
# Jonathan Hosein                   1
# vikram Reddy                      1
# Length: 1330, dtype: int64

# %%
#name='pdaniel'
L=df1.loc[df1['ï»¿"User ID (v14) (evar14)"'] == name]
L1=pd.DataFrame(L[['Header Item Clicked (v56) (evar56)']],columns= ['Header Item Clicked (v56) (evar56)'])
L2=pd.DataFrame(L[['Search Result Clicked Title (v23) (evar23)']],columns= ['Search Result Clicked Title (v23) (evar23)'])

Li1=L1.rename(columns={"Header Item Clicked (v56) (evar56)": "Color"})
Li2=L2.rename(columns={"Search Result Clicked Title (v23) (evar23)": "Color"})

vee=pd.concat([Li1 ,Li2])
dups_color2 = vee.pivot_table(index=['Color'], aggfunc='size').sort_values(ascending=False)

# %%
dups_color2
# Out:
# Color
# Rosslyn                                                   3
# Deloitte University                                       3
# Deloitte Connect                                          2
# Work                                                      1
# My Compliance > Ethics & Compliance > Can I mobile app    1
# Africa                                                    1
# Brazil                                                    1
# Caribbean & Bermuda                                       1
# DeloitteNet                                               1
# Global                                                    1
# Nossa firma > Nossa firma > 175 anos de Deloitte          1
# Trips                                                     1
# Nossa firma > Nossa firma > Cultura CRER                  1
# Rate this App                                             1
# Ravi Ravi                                                 1
# Self-Service Communications Site                          1
# ServiceNow Digital Self Service                           1
# Tools                                                     1
# Admin                                                     1
# dtype: int64

# %%
d1=pd.DataFrame(dups_color,columns= ['Count'])
d2=pd.DataFrame(dups_color2,columns= ['Count'])

# %%
d1.head(20)
# Out:
#                                                     Count
# Color
# DTE: Deloitte Time & Expense                          798
# TOD: Talent On Demand                                 632
# Talent On Demand                                      510
# My Technology                                         489
# Tools                                                 434
# DeloitteNet                                           405
# Deloitte Software Catalog                             262
# Work                                                  239
# Multi-Factor Authentication (MFA)                     237
# iRPM - Reinventing Performance Management             224
# USI PDA                                               199
# My Compliance Dashboard (MCD)                         188
# ServiceNow Digital Self Service                       185
# My Information                                        163
# Deloitte 2020 Holidays                                161
# Mobile Devices                                        142
# News                                                  142
# Top Links > Top Links > Deloitte Time & Expense...    136
# Deloitte Survey Tool                                  130
# Outlook                                               126
