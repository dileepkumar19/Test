# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
from itertools import cycle, islice
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

# %matplotlib inline

# %%
data = pd.read_csv('Report_user (3).csv',encoding='ISO-8859-1')

# %%
data.shape
# Out:
# (2532437, 22)

# %%
data.head()
# Out:
#   ï»¿"User ID (v14) (evar14)" Tenure (yrs) Subregion Service Line  \
# 0          100robot.jupiter01          NaN       NaN          NaN
# 1                     a-adrar          NaN       NaN          NaN
# 2                      a-aneo          NaN       NaN          NaN
# 3                      a-aneo          NaN       NaN          NaN
# 4            a-ashutoshkumar2          NaN       NaN          NaN
#
#   Service Area Office Member Firm Level Local Level Function Local  ...  \
# 0          NaN    NaN         NaN         NaN   NaN            NaN  ...
# 1          NaN    NaN         NaN         NaN   NaN            NaN  ...
# 2          NaN    NaN         NaN         NaN   NaN            NaN  ...
# 3          NaN    NaN         NaN         NaN   NaN            NaN  ...
# 4          NaN    NaN         NaN         NaN   NaN            NaN  ...
#
#   Header Area Clicked (v55) (evar55) Header Item Clicked (v56) (evar56)  \
# ...

# %%
sampled_df = data
sampled_df.shape
# Out:
# (2532437, 22)

# %%
sampled_df.describe().transpose()
# Out:
#                                                 count  unique  \
# ï»¿"User ID (v14) (evar14)"                   2532437  237537
# Tenure (yrs)                                  2504903       7
# Subregion                                     2504903       1
# Service Line                                  2504903     117
# Service Area                                  2504903      62
# Office                                        2504903       1
# Member Firm                                   2504903      40
# Level Local                                   2504903     130
# Level                                         2504903      11
# Function Local                                2504903      48
# Function                                      2504903      10
# Country                                       2504903     147
# Header Area Clicked (v55) (evar55)             305448       6
# Header Item Clicked (v56) (evar56)             305448    3631
# ...

# %%
sampled_df[sampled_df['Header Area Clicked (v55) (evar55)']== 0].shape
# Out:
# (0, 22)

# %%
len(sampled_df['Header Area Clicked (v55) (evar55)'])
# Out:
# 2532437

# %%
sampled_df.columns
# Out:
# Index(['ï»¿"User ID (v14) (evar14)"', 'Tenure (yrs)', 'Subregion',
#        'Service Line', 'Service Area', 'Office', 'Member Firm', 'Level Local',
#        'Level', 'Function Local', 'Function', 'Country',
#        'Header Area Clicked (v55) (evar55)',
#        'Header Item Clicked (v56) (evar56)',
#        'Search Result Clicked Detail (v60) (evar60)',
#        'Search Result Clicked Subtype (v59) (evar59)',
#        'Search Result Clicked Title (v23) (evar23)',
#        'Search Result Clicked Type (v58) (evar58)',
#        'Search Type (v25) (evar25)', 'Search Terms (v26) (evar26)',
#        'Capability', 'Breadcrumb (v9) (evar9)'],
#       dtype='object')

# %%
features = ['Tenure (yrs)', 'Service Line', 'Service Area', 'Office', 'Member Firm','Level','Function']

# %%
select_df = sampled_df[features]

# %%
select_df.columns
# Out:
# Index(['Tenure (yrs)', 'Service Line', 'Service Area', 'Office', 'Member Firm',
#        'Level', 'Function'],
#       dtype='object')

# %%
select_df
# Out:
#         Tenure (yrs)      Service Line                      Service Area  \
# 0                NaN               NaN                               NaN
# 1                NaN               NaN                               NaN
# 2                NaN               NaN                               NaN
# 3                NaN               NaN                               NaN
# 4                NaN               NaN                               NaN
# ...              ...               ...                               ...
# 2532432      6 to 10    Internal Audit  Accounting and Internal Controls
# 2532433      6 to 10    Internal Audit  Accounting and Internal Controls
# 2532434  Less than 1  Data Field Blank                     Human Capital
# 2532435  Less than 1  Data Field Blank                     Human Capital
# 2532436  Less than 1  Data Field Blank                     Human Capital
#
#                    Office    Member Firm         Level       Function
# ...

# %%
X = StandardScaler().fit_transform(select_df.value_counts().index)
X
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-20c36db0caf8> in <module>
# ----> 1 X = StandardScaler().fit_transform(select_df.value_counts().index)
#       2 X
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
len(select_df.values)
# Out:
# 2532437

# %%
X.reshape(-1, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-1e2c2dd0698d> in <module>
# ----> 1 X.reshape(-1, 1)
#
# NameError: name 'X' is not defined

# %%
kmeans = KMeans(n_clusters=12)
model = kmeans.fit(X)
print("model\n", model)
