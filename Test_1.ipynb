# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
analytics = pd.read_csv('Report_user (3).csv',encoding='ISO-8859-1')
analytics
# Out:
#         ï»¿"User ID (v14) (evar14)" Tenure (yrs)         Subregion  \
# 0                100robot.jupiter01          NaN               NaN
# 1                           a-adrar          NaN               NaN
# 2                            a-aneo          NaN               NaN
# 3                            a-aneo          NaN               NaN
# 4                  a-ashutoshkumar2          NaN               NaN
# ...                             ...          ...               ...
# 2532432                     zzuberi      6 to 10  Data Field Blank
# 2532433                     zzuberi      6 to 10  Data Field Blank
# 2532434                      zzwane  Less than 1  Data Field Blank
# 2532435                      zzwane  Less than 1  Data Field Blank
# 2532436                      zzwane  Less than 1  Data Field Blank
#
#              Service Line                      Service Area            Office  \
# 0                     NaN                               NaN               NaN
# ...

# %%
ax = sns.countplot(y="Level", data=analytics,order=analytics.Level.value_counts().iloc[:10].index)

# %%
analytics.Level.value_counts()
# Out:
# Senior                  555494
# Staff                   486767
# Manager                 479422
# Senior Manager          314006
# Junior Staff            283229
# Administrative Staff    166144
# Director                117889
# Partner                  95056
# Associate Director        4850
# Data Field Blank          1699
# Not Applicable             347
# Name: Level, dtype: int64

# %%
ax = sns.countplot(y="Member Firm", data=analytics,order=analytics['Member Firm'].value_counts().iloc[:10].index)

# %%
analytics['Member Firm'].value_counts()
# Out:
# United States                         1459005
# North and South Europe                 693714
# Deloitte DCE                           136898
# Asia Pacific                            49766
# India                                   45747
# Brazil                                  36442
# Portugal                                25849
# Africa                                  19136
# S-LATAM                                 10804
# Canada                                   9603
# Spain                                    5031
# Caribbean and Bermuda                    5007
# Turkey                                   4643
# Pakistan                                  748
# Commonwealth of Independent States        586
# Central Europe                            349
# United Kingdom                            240
# North West Europe                         202
# France                                    191
# Central Mediterranean                     180
# ...

# %%
ax = sns.countplot(y="Header Area Clicked (v55) (evar55)", data=analytics,order=analytics['Header Area Clicked (v55) (evar55)'].value_counts().iloc[:10].index)

# %%
ax = sns.countplot(y="Header Item Clicked (v56) (evar56)", data=analytics,order=analytics['Header Item Clicked (v56) (evar56)'].value_counts().iloc[:10].index)

# %%
ax = sns.countplot(y="Search Result Clicked Type (v58) (evar58)", data=analytics,order=analytics['Search Result Clicked Type (v58) (evar58)'].value_counts().iloc[:5].index)

# %%
ax = sns.countplot(y=analytics['Search Type (v25) (evar25)'].value_counts().values, data=analytics,order=analytics['Search Type (v25) (evar25)'].value_counts().iloc[:10].values)
plt.legend(loc=0)
# Out:
# No handles with labels found to put in legend.

# %%
sns.relplot(
    data=analytics,x=analytics['Search Result Clicked Subtype (v59) (evar59)'].value_counts().index,
    y=analytics['Search Result Clicked Subtype (v59) (evar59)'].value_counts().values
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-0d7cc077761f> in <module>
# ----> 1 sns.relplot(
#       2     data=analytics,x=analytics['Search Result Clicked Subtype (v59) (evar59)'].value_counts().index,
#       3     y=analytics['Search Result Clicked Subtype (v59) (evar59)'].value_counts().values
#       4 )
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1693
#    1694     # Draw the plot
# -> 1695     g.map_dataframe(func, x, y,
#    1696                     hue=hue, size=size, style=style,
#    1697                     **plot_kws)
#
# ...

# %%
analytics['Search Type (v25) (evar25)'].unique()
# Out:
# array([nan, 'Instant Find DIGS Search', 'Instant Find', 'Search overview',
#        'DeloitteResources results'], dtype=object)

# %%
analytics['Search Result Clicked Subtype (v59) (evar59)'].unique()
# Out:
# array([nan, 'Apps', 'Pages', 'DDT', 'People', 'Offices'], dtype=object)

# %%
sns.relplot(
    data=analytics, kind="line",y=analytics['Search Type (v25) (evar25)'].value_counts().values,
    x=analytics['Search Type (v25) (evar25)'].value_counts().index,
    facet_kws=dict(sharex=False)
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-c2c1f2aad627> in <module>
# ----> 1 sns.relplot(
#       2     data=analytics, kind="line",y=analytics['Search Type (v25) (evar25)'].value_counts().values,
#       3     x=analytics['Search Type (v25) (evar25)'].value_counts().index,
#       4     facet_kws=dict(sharex=False)
#       5 )
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1693
#    1694     # Draw the plot
# -> 1695     g.map_dataframe(func, x, y,
#    1696                     hue=hue, size=size, style=style,
#    1697                     **plot_kws)
#
# ...

# %%
analytics['Search Type (v25) (evar25)'].value_counts().index
# Out:
# Index(['Instant Find', 'Instant Find DIGS Search', 'Search overview',
#        'DeloitteResources results'],
#       dtype='object')

# %%
analytics['Search Type (v25) (evar25)'].value_counts().values
# Out:
# array([715833, 253416,  18705,    757], dtype=int64)

# %%
plt.figure(figsize=(7,7))
ax=sns.barplot(x=analytics['Search Type (v25) (evar25)'].value_counts().index,y=analytics['Search Type (v25) (evar25)'].value_counts().values,palette="Blues_d")
plt.legend(loc=8)
plt.xlabel('Search Type (v25) (evar25)')
plt.ylabel('Frequency')
plt.title('Show of Gender Bar Plot')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,7))
sns.barplot(x = analytics['Search Type (v25) (evar25)'].value_counts().index, y = analytics['Search Type (v25) (evar25)'].value_counts().values, data = analytics)
plt.xticks(rotation=45)
plt.show()

# %%
analytics['Search Result Clicked Subtype (v59) (evar59)'].unique()
# Out:
# array([nan, 'Apps', 'Pages', 'DDT', 'People', 'Offices'], dtype=object)

# %%
analytics['Search Result Clicked Type (v58) (evar58)'].unique()
# Out:
# array([nan, 'Instant Find Result', 'Instant Find Answer Card Result',
#        'Search overview > DeloitteNet results',
#        'Search overview > Enterprise Search results',
#        'DeloitteResources results > DeloitteNet Result',
#        'Search overview > Promoted Result',
#        'DeloitteResources results > Promoted Result'], dtype=object)

# %%
data=analytics
#Gender show point plot
data['Search Result Clicked Subtype (v59) (evar59)'].unique()
# Out:
# array([nan, 'Apps', 'Pages', 'DDT', 'People', 'Offices'], dtype=object)

# %%
rt=len(data[(data['Search Result Clicked Subtype (v59) (evar59)']=='Apps')].Level)

# %%
#Gender show point plot
data['Search Result Clicked Subtype (v59) (evar59)'].unique()
ct=len(data[(data['Search Result Clicked Subtype (v59) (evar59)']=='Apps')].Level)
ct
# Out:
# 302336

# %%
f,ax1=plt.subplots(figsize=(25,10))
tyu=data[(data['Search Result Clicked Subtype (v59) (evar59)']=='Apps')]
sns.pointplot(y=tyu.index,x=tyu['Member Firm'],color='lime',alpha=0.2)
sns.pointplot(y=tyu.index,x=tyu['Service Line'],color='red',alpha=0.4)
sns.pointplot(y=tyu.index,x=tyu['Service Area'],color='blue',alpha=0.6)
sns.pointplot(y=tyu.index,x=tyu['Level'],color='red',alpha=0.8)
sns.pointplot(y=tyu.index,x=tyu['ï»¿"User ID (v14) (evar14)"'],color='red',alpha=0.8)

# %%
xyz=len(data[(data['Search Result Clicked Subtype (v59) (evar59)']=='Apps')].index)
xyz
# Out:
# 302336
