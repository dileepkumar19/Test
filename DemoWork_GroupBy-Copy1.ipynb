# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Report20200501-20201030.csv', nrows=5000000,encoding='ISO-8859-1',parse_dates=['ï»¿"Date"'])

# %%
df['ï»¿"Date"']=df['ï»¿"Date"'].dt.day_name()

# %%
df.describe().transpose()
# Out:
#                                                 count  unique  \
# ï»¿"Date"                                     5000000       7
# User ID (v14) (evar14)                        5000000  211335
# Service Line                                  4980854     108
# Service Line Local                            4980854     874
# Service Area                                  4980854      60
# Service Area Local                            4980854     502
# Member Firm                                   4980854      37
# Level Local                                   4980854     128
# Level                                         4980854      11
# Function Local                                4980854      47
# Function                                      4980854      11
# Deloitte Network Intranet (v51) (evar51)      5000000      43
# Header Area Clicked (v55) (evar55)             840665       6
# Header Item Clicked (v56) (evar56)             840665    3487
# Search Result Clicked Subtype (v59) (evar59)  1420754       5
# Search Result Clicked Title (v23) (evar23)    1468477   65948
#
#                                                                        top  \
# ï»¿"Date"                                                          Tuesday
# User ID (v14) (evar14)                                         cmilcinovic
# Service Line                                              Data Field Blank
# Service Line Local                                        Data Field Blank
# Service Area                                              Data Field Blank
# Service Area Local                                        Data Field Blank
# Member Firm                                                  United States
# Level Local                                                         Senior
# Level                                                               Senior
# Function Local                                                  Consulting
# Function                                                        Consulting
# Deloitte Network Intranet (v51) (evar51)                     United States
# Header Area Clicked (v55) (evar55)                            App Launcher
# Header Item Clicked (v56) (evar56)                                   SWIFT
# Search Result Clicked Subtype (v59) (evar59)                          Apps
# Search Result Clicked Title (v23) (evar23)    DTE: Deloitte Time & Expense
#
#                                                  freq
# ï»¿"Date"                                     1008420
# User ID (v14) (evar14)                            740
# Service Line                                  3041907
# Service Line Local                            1961714
# Service Area                                   833413
# Service Area Local                             825532
# Member Firm                                   3225007
# Level Local                                    992505
# Level                                         1250639
# Function Local                                1528917
# Function                                      1708500
# Deloitte Network Intranet (v51) (evar51)      3218492
# Header Area Clicked (v55) (evar55)             441123
# Header Item Clicked (v56) (evar56)             109684
# Search Result Clicked Subtype (v59) (evar59)   797634
# Search Result Clicked Title (v23) (evar23)     237250

# %%
name='rperla'
dfd=df.loc[df['User ID (v14) (evar14)'] == name]
dfd
# Out:
#          ï»¿"Date" User ID (v14) (evar14)      Service Line  \
# 328620      Monday                 rperla  Data Field Blank
# 499117     Tuesday                 rperla  Data Field Blank
# 499118     Tuesday                 rperla  Data Field Blank
# 659432   Wednesday                 rperla  Data Field Blank
# 659433   Wednesday                 rperla  Data Field Blank
# 659434   Wednesday                 rperla  Data Field Blank
# 819988    Thursday                 rperla  Data Field Blank
# 960755      Friday                 rperla  Data Field Blank
# 1197664     Monday                 rperla  Data Field Blank
# 1370711    Tuesday                 rperla  Data Field Blank
# 1370712    Tuesday                 rperla  Data Field Blank
# 1536304  Wednesday                 rperla  Data Field Blank
# 1536305  Wednesday                 rperla  Data Field Blank
# 1536306  Wednesday                 rperla  Data Field Blank
# 1536307  Wednesday                 rperla  Data Field Blank
# 1536308  Wednesday                 rperla  Data Field Blank
# 1536309  Wednesday                 rperla  Data Field Blank
# 1536310  Wednesday                 rperla  Data Field Blank
# 1536311  Wednesday                 rperla  Data Field Blank
# 2115092     Monday                 rperla  Data Field Blank
# 2115093     Monday                 rperla  Data Field Blank
# 2283861    Tuesday                 rperla  Data Field Blank
# 2445074  Wednesday                 rperla  Data Field Blank
# 2731426     Friday                 rperla  Data Field Blank
# 2731427     Friday                 rperla  Data Field Blank
# 3020629    Tuesday                 rperla  Data Field Blank
# 3020630    Tuesday                 rperla  Data Field Blank
# 3195795  Wednesday                 rperla  Data Field Blank
# 3195796  Wednesday                 rperla  Data Field Blank
# 3195797  Wednesday                 rperla  Data Field Blank
# 3195798  Wednesday                 rperla  Data Field Blank
# 3375153   Thursday                 rperla  Data Field Blank
# 3562377     Friday                 rperla  Data Field Blank
# 3629510   Saturday                 rperla  Data Field Blank
# 3664340     Sunday                 rperla  Data Field Blank
# 3814358     Monday                 rperla  Data Field Blank
# 3814359     Monday                 rperla  Data Field Blank
# 3814360     Monday                 rperla  Data Field Blank
# 3978469    Tuesday                 rperla  Data Field Blank
# 3978470    Tuesday                 rperla  Data Field Blank
# 3978471    Tuesday                 rperla  Data Field Blank
# 3978472    Tuesday                 rperla  Data Field Blank
# 4466610     Friday                 rperla  Data Field Blank
# 4555167     Sunday                 rperla  Data Field Blank
# 4705221     Monday                 rperla  Data Field Blank
# 4876947    Tuesday                 rperla  Data Field Blank
#
#                 Service Line Local            Service Area Service Area Local  \
# 328620   DAS Unity, Collab and ARM  Information Technology                DAS
# 499117   DAS Unity, Collab and ARM  Information Technology                DAS
# 499118   DAS Unity, Collab and ARM  Information Technology                DAS
# 659432   DAS Unity, Collab and ARM  Information Technology                DAS
# 659433   DAS Unity, Collab and ARM  Information Technology                DAS
# 659434   DAS Unity, Collab and ARM  Information Technology                DAS
# 819988   DAS Unity, Collab and ARM  Information Technology                DAS
# 960755   DAS Unity, Collab and ARM  Information Technology                DAS
# 1197664  DAS Unity, Collab and ARM  Information Technology                DAS
# 1370711  DAS Unity, Collab and ARM  Information Technology                DAS
# 1370712  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536304  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536305  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536306  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536307  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536308  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536309  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536310  DAS Unity, Collab and ARM  Information Technology                DAS
# 1536311  DAS Unity, Collab and ARM  Information Technology                DAS
# 2115092  DAS Unity, Collab and ARM  Information Technology                DAS
# 2115093  DAS Unity, Collab and ARM  Information Technology                DAS
# 2283861  DAS Unity, Collab and ARM  Information Technology                DAS
# 2445074  DAS Unity, Collab and ARM  Information Technology                DAS
# 2731426  DAS Unity, Collab and ARM  Information Technology                DAS
# 2731427  DAS Unity, Collab and ARM  Information Technology                DAS
# 3020629  DAS Unity, Collab and ARM  Information Technology                DAS
# 3020630  DAS Unity, Collab and ARM  Information Technology                DAS
# 3195795  DAS Unity, Collab and ARM  Information Technology                DAS
# 3195796  DAS Unity, Collab and ARM  Information Technology                DAS
# 3195797  DAS Unity, Collab and ARM  Information Technology                DAS
# 3195798  DAS Unity, Collab and ARM  Information Technology                DAS
# 3375153  DAS Unity, Collab and ARM  Information Technology                DAS
# 3562377  DAS Unity, Collab and ARM  Information Technology                DAS
# 3629510  DAS Unity, Collab and ARM  Information Technology                DAS
# 3664340  DAS Unity, Collab and ARM  Information Technology                DAS
# 3814358  DAS Unity, Collab and ARM  Information Technology                DAS
# 3814359  DAS Unity, Collab and ARM  Information Technology                DAS
# 3814360  DAS Unity, Collab and ARM  Information Technology                DAS
# 3978469  DAS Unity, Collab and ARM  Information Technology                DAS
# 3978470  DAS Unity, Collab and ARM  Information Technology                DAS
# 3978471  DAS Unity, Collab and ARM  Information Technology                DAS
# 3978472  DAS Unity, Collab and ARM  Information Technology                DAS
# 4466610  DAS Unity, Collab and ARM  Information Technology                DAS
# 4555167  DAS Unity, Collab and ARM  Information Technology                DAS
# 4705221  DAS Unity, Collab and ARM  Information Technology                DAS
# 4876947  DAS Unity, Collab and ARM  Information Technology                DAS
#
#            Member Firm Level Local    Level   Function Local  \
# 328620   United States     Manager  Manager  Technology (IS)
# 499117   United States     Manager  Manager  Technology (IS)
# 499118   United States     Manager  Manager  Technology (IS)
# 659432   United States     Manager  Manager  Technology (IS)
# 659433   United States     Manager  Manager  Technology (IS)
# 659434   United States     Manager  Manager  Technology (IS)
# 819988   United States     Manager  Manager  Technology (IS)
# 960755   United States     Manager  Manager  Technology (IS)
# 1197664  United States     Manager  Manager  Technology (IS)
# 1370711  United States     Manager  Manager  Technology (IS)
# 1370712  United States     Manager  Manager  Technology (IS)
# 1536304  United States     Manager  Manager  Technology (IS)
# 1536305  United States     Manager  Manager  Technology (IS)
# 1536306  United States     Manager  Manager  Technology (IS)
# 1536307  United States     Manager  Manager  Technology (IS)
# 1536308  United States     Manager  Manager  Technology (IS)
# 1536309  United States     Manager  Manager  Technology (IS)
# 1536310  United States     Manager  Manager  Technology (IS)
# 1536311  United States     Manager  Manager  Technology (IS)
# 2115092  United States     Manager  Manager  Technology (IS)
# 2115093  United States     Manager  Manager  Technology (IS)
# 2283861  United States     Manager  Manager  Technology (IS)
# 2445074  United States     Manager  Manager  Technology (IS)
# 2731426  United States     Manager  Manager  Technology (IS)
# 2731427  United States     Manager  Manager  Technology (IS)
# 3020629  United States     Manager  Manager  Technology (IS)
# 3020630  United States     Manager  Manager  Technology (IS)
# 3195795  United States     Manager  Manager  Technology (IS)
# 3195796  United States     Manager  Manager  Technology (IS)
# 3195797  United States     Manager  Manager  Technology (IS)
# 3195798  United States     Manager  Manager  Technology (IS)
# 3375153  United States     Manager  Manager  Technology (IS)
# 3562377  United States     Manager  Manager  Technology (IS)
# 3629510  United States     Manager  Manager  Technology (IS)
# 3664340  United States     Manager  Manager  Technology (IS)
# 3814358  United States     Manager  Manager  Technology (IS)
# 3814359  United States     Manager  Manager  Technology (IS)
# 3814360  United States     Manager  Manager  Technology (IS)
# 3978469  United States     Manager  Manager  Technology (IS)
# 3978470  United States     Manager  Manager  Technology (IS)
# 3978471  United States     Manager  Manager  Technology (IS)
# 3978472  United States     Manager  Manager  Technology (IS)
# 4466610  United States     Manager  Manager  Technology (IS)
# 4555167  United States     Manager  Manager  Technology (IS)
# 4705221  United States     Manager  Manager  Technology (IS)
# 4876947  United States     Manager  Manager  Technology (IS)
#
#                   Function Deloitte Network Intranet (v51) (evar51)  \
# 328620   Internal Services                            United States
# 499117   Internal Services                            United States
# 499118   Internal Services                            United States
# 659432   Internal Services                           United Kingdom
# 659433   Internal Services                           United Kingdom
# 659434   Internal Services                            United States
# 819988   Internal Services                            United States
# 960755   Internal Services                            United States
# 1197664  Internal Services                            United States
# 1370711  Internal Services                            United States
# 1370712  Internal Services                            United States
# 1536304  Internal Services                                   Africa
# 1536305  Internal Services                                   Africa
# 1536306  Internal Services                                   Africa
# 1536307  Internal Services                                   Africa
# 1536308  Internal Services                            United States
# 1536309  Internal Services                            United States
# 1536310  Internal Services                            United States
# 1536311  Internal Services                            United States
# 2115092  Internal Services                            United States
# 2115093  Internal Services                            United States
# 2283861  Internal Services                            United States
# 2445074  Internal Services                            United States
# 2731426  Internal Services                                     Help
# 2731427  Internal Services                            United States
# 3020629  Internal Services                            United States
# 3020630  Internal Services                            United States
# 3195795  Internal Services                      Caribbean & Bermuda
# 3195796  Internal Services                            United States
# 3195797  Internal Services                            United States
# 3195798  Internal Services                            United States
# 3375153  Internal Services                            United States
# 3562377  Internal Services                            United States
# 3629510  Internal Services                            United States
# 3664340  Internal Services                            United States
# 3814358  Internal Services                            United States
# 3814359  Internal Services                            United States
# 3814360  Internal Services                            United States
# 3978469  Internal Services                           United Kingdom
# 3978470  Internal Services                           United Kingdom
# 3978471  Internal Services                            United States
# 3978472  Internal Services                            United States
# 4466610  Internal Services                            United States
# 4555167  Internal Services                            United States
# 4705221  Internal Services                            United States
# 4876947  Internal Services                            United States
#
#         Header Area Clicked (v55) (evar55)  \
# 328620                                 NaN
# 499117                                 NaN
# 499118                        Top Nav Menu
# 659432                                 NaN
# 659433                        Sidebar Menu
# 659434                                 NaN
# 819988                                 NaN
# 960755                                 NaN
# 1197664                                NaN
# 1370711                                NaN
# 1370712                                NaN
# 1536304                                NaN
# 1536305                       Sidebar Menu
# 1536306                       Top Nav Menu
# 1536307                       Top Nav Menu
# 1536308                                NaN
# 1536309                Sidebar Member Firm
# 1536310                Sidebar Member Firm
# 1536311                       Sidebar Menu
# 2115092                                NaN
# 2115093                       App Launcher
# 2283861                                NaN
# 2445074                                NaN
# 2731426                                NaN
# 2731427                                NaN
# 3020629                                NaN
# 3020630                       Top Nav Menu
# 3195795                                NaN
# 3195796                                NaN
# 3195797                       Top Nav Menu
# 3195798                       Top Nav Menu
# 3375153                                NaN
# 3562377                                NaN
# 3629510                                NaN
# 3664340                                NaN
# 3814358                                NaN
# 3814359                       Top Nav Menu
# 3814360                       Top Nav Menu
# 3978469                                NaN
# 3978470                       Sidebar Menu
# 3978471                                NaN
# 3978472                Sidebar Member Firm
# 4466610                                NaN
# 4555167                                NaN
# 4705221                       Top Nav Menu
# 4876947                                NaN
#
#                         Header Item Clicked (v56) (evar56)  \
# 328620                                                 NaN
# 499117                                                 NaN
# 499118                                                Work
# 659432                                                 NaN
# 659433             Time, travel & finance > Pages > Travel
# 659434                                                 NaN
# 819988                                                 NaN
# 960755                                                 NaN
# 1197664                                                NaN
# 1370711                                                NaN
# 1370712                                                NaN
# 1536304                                                NaN
# 1536305  Deloitte West Africa > People > Talent Policie...
# 1536306                                        DeloitteNet
# 1536307                                               News
# 1536308                                                NaN
# 1536309                                             Africa
# 1536310                                            Baltics
# 1536311   Client & Market Growth > Top Links > CIO Program
# 2115092                                                NaN
# 2115093                                            Outlook
# 2283861                                                NaN
# 2445074                                                NaN
# 2731426                                                NaN
# 2731427                                                NaN
# 3020629                                                NaN
# 3020630                                              Admin
# 3195795                                                NaN
# 3195796                                                NaN
# 3195797                                        DeloitteNet
# 3195798                                               Work
# 3375153                                                NaN
# 3562377                                                NaN
# 3629510                                                NaN
# 3664340                                                NaN
# 3814358                                                NaN
# 3814359                                              Tools
# 3814360                                               Work
# 3978469                                                NaN
# 3978470  Clients > Going to market > Offerings by clien...
# 3978471                                                NaN
# 3978472                                     United Kingdom
# 4466610                                                NaN
# 4555167                                                NaN
# 4705221                                              Admin
# 4876947                                                NaN
#
#         Search Result Clicked Subtype (v59) (evar59)  \
# 328620                                           NaN
# 499117                                           NaN
# 499118                                           NaN
# 659432                                           NaN
# 659433                                           NaN
# 659434                                           NaN
# 819988                                           NaN
# 960755                                           NaN
# 1197664                                          NaN
# 1370711                                          NaN
# 1370712                                      Offices
# 1536304                                          NaN
# 1536305                                          NaN
# 1536306                                          NaN
# 1536307                                          NaN
# 1536308                                          NaN
# 1536309                                          NaN
# 1536310                                          NaN
# 1536311                                          NaN
# 2115092                                          NaN
# 2115093                                          NaN
# 2283861                                          NaN
# 2445074                                          NaN
# 2731426                                          NaN
# 2731427                                          NaN
# 3020629                                          NaN
# 3020630                                          NaN
# 3195795                                          NaN
# 3195796                                          NaN
# 3195797                                          NaN
# 3195798                                          NaN
# 3375153                                          NaN
# 3562377                                          NaN
# 3629510                                          NaN
# 3664340                                          NaN
# 3814358                                          NaN
# 3814359                                          NaN
# 3814360                                          NaN
# 3978469                                          NaN
# 3978470                                          NaN
# 3978471                                          NaN
# 3978472                                          NaN
# 4466610                                          NaN
# 4555167                                          NaN
# 4705221                                          NaN
# 4876947                                          NaN
#
#         Search Result Clicked Title (v23) (evar23)
# 328620                                         NaN
# 499117                                         NaN
# 499118                                         NaN
# 659432                                         NaN
# 659433                                         NaN
# 659434                                         NaN
# 819988                                         NaN
# 960755                                         NaN
# 1197664                                        NaN
# 1370711                                        NaN
# 1370712                                    Chicago
# 1536304                                        NaN
# 1536305                                        NaN
# 1536306                                        NaN
# 1536307                                        NaN
# 1536308                                        NaN
# 1536309                                        NaN
# 1536310                                        NaN
# 1536311                                        NaN
# 2115092                                        NaN
# 2115093                                        NaN
# 2283861                                        NaN
# 2445074                                        NaN
# 2731426                                        NaN
# 2731427                                        NaN
# 3020629                                        NaN
# 3020630                                        NaN
# 3195795                                        NaN
# 3195796                                        NaN
# 3195797                                        NaN
# 3195798                                        NaN
# 3375153                                        NaN
# 3562377                                        NaN
# 3629510                                        NaN
# 3664340                                        NaN
# 3814358                                        NaN
# 3814359                                        NaN
# 3814360                                        NaN
# 3978469                                        NaN
# 3978470                                        NaN
# 3978471                                        NaN
# 3978472                                        NaN
# 4466610                                        NaN
# 4555167                                        NaN
# 4705221                                        NaN
# 4876947                                        NaN

# %%
Group=df.groupby(['ï»¿"Date"','Service Line Local','Service Area Local','Function Local','Member Firm','Level Local','Deloitte Network Intranet (v51) (evar51)'])
group2=Group['User ID (v14) (evar14)'] 
group3=Group['Header Area Clicked (v55) (evar55)']
group4=Group['Header Item Clicked (v56) (evar56)']
group5=Group['Search Result Clicked Subtype (v59) (evar59)']
group6=Group['Search Result Clicked Title (v23) (evar23)']

# %%
group2.describe()
# Out:
#                                                                                                                                                                                          count  \
# ï»¿"Date" Service Line Local          Service Area Local              Function Local       Member Firm            Level Local                   Deloitte Network Intranet (v51) (evar51)
# Friday    ACF M&A                     Corporate Finance Advisory      Financial Advisory   North West Europe      Assistant Director            United Kingdom                               1
#                                                                                                                   Executive                     United Kingdom                               6
#                                                                                            North and South Europe Assistant Director            NWE-Shared                                   1
#                                                                                                                                                 United Kingdom                             257
#                                                                                                                   Assistant Manager             United Kingdom                              11
# ...                                                                                                                                                                                        ...
# Wednesday Workforce Transformation    Human Capital                   Consulting           United States          USDC Senior/Senior Consultant United States                               28
#                                                                                                                   USDC Sr. Manager              United States                                3
#                                                                                                                   USDC Staff/Consultant         United States                               56
#           Workplace Experience Leader Workplace Experience Leadership Workplace Experience United States          Managing Director             United States                               19
#                                                                                                                   Senior Manager                United States                                6
#
#                                                                                                                                                                                          unique  \
# ï»¿"Date" Service Line Local          Service Area Local              Function Local       Member Firm            Level Local                   Deloitte Network Intranet (v51) (evar51)
# Friday    ACF M&A                     Corporate Finance Advisory      Financial Advisory   North West Europe      Assistant Director            United Kingdom                                1
#                                                                                                                   Executive                     United Kingdom                                1
#                                                                                            North and South Europe Assistant Director            NWE-Shared                                    1
#                                                                                                                                                 United Kingdom                               37
#                                                                                                                   Assistant Manager             United Kingdom                                1
# ...                                                                                                                                                                                         ...
# Wednesday Workforce Transformation    Human Capital                   Consulting           United States          USDC Senior/Senior Consultant United States                                 5
#                                                                                                                   USDC Sr. Manager              United States                                 1
#                                                                                                                   USDC Staff/Consultant         United States                                 9
#           Workplace Experience Leader Workplace Experience Leadership Workplace Experience United States          Managing Director             United States                                 4
#                                                                                                                   Senior Manager                United States                                 1
#
#                                                                                                                                                                                                         top  \
# ï»¿"Date" Service Line Local          Service Area Local              Function Local       Member Firm            Level Local                   Deloitte Network Intranet (v51) (evar51)
# Friday    ACF M&A                     Corporate Finance Advisory      Financial Advisory   North West Europe      Assistant Director            United Kingdom                                 nmaduvinkody
#                                                                                                                   Executive                     United Kingdom                            emiliaszabadosova
#                                                                                            North and South Europe Assistant Director            NWE-Shared                                          gregcox
#                                                                                                                                                 United Kingdom                                     jwanless
#                                                                                                                   Assistant Manager             United Kingdom                                       haguda
# ...                                                                                                                                                                                                     ...
# Wednesday Workforce Transformation    Human Capital                   Consulting           United States          USDC Senior/Senior Consultant United States                                   dthomasjohn
#                                                                                                                   USDC Sr. Manager              United States                                       ssurges
#                                                                                                                   USDC Staff/Consultant         United States                                       shareid
#           Workplace Experience Leader Workplace Experience Leadership Workplace Experience United States          Managing Director             United States                                  acooperdavis
#                                                                                                                   Senior Manager                United States                                       mfinaly
#
#                                                                                                                                                                                          freq
# ï»¿"Date" Service Line Local          Service Area Local              Function Local       Member Firm            Level Local                   Deloitte Network Intranet (v51) (evar51)
# Friday    ACF M&A                     Corporate Finance Advisory      Financial Advisory   North West Europe      Assistant Director            United Kingdom                              1
#                                                                                                                   Executive                     United Kingdom                              6
#                                                                                            North and South Europe Assistant Director            NWE-Shared                                  1
#                                                                                                                                                 United Kingdom                             18
#                                                                                                                   Assistant Manager             United Kingdom                             11
# ...                                                                                                                                                                                       ...
# Wednesday Workforce Transformation    Human Capital                   Consulting           United States          USDC Senior/Senior Consultant United States                               9
#                                                                                                                   USDC Sr. Manager              United States                               3
#                                                                                                                   USDC Staff/Consultant         United States                              14
#           Workplace Experience Leader Workplace Experience Leadership Workplace Experience United States          Managing Director             United States                               6
#                                                                                                                   Senior Manager                United States                               6
#
# [62232 rows x 4 columns]

# %%
GroupByDay=df.groupby('ï»¿"Date"')
GroupByDay.describe().transpose()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-24-cf95cf4c9841> in <module>
#       1 GroupByDay=df.groupby('ï»¿"Date"')
# ----> 2 GroupByDay.describe().transpose()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in describe(self, **kwargs)
#    1444     def describe(self, **kwargs):
#    1445         with _group_selection_context(self):
# -> 1446             result = self.apply(lambda x: x.describe(**kwargs))
#    1447             if self.axis == 1:
#    1448                 return result.T
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     734         with option_context("mode.chained_assignment", None):
#     735             try:
# --> 736                 result = self._python_apply_general(f)
#     737             except TypeError:
#     738                 # gh-20949
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     750
#     751     def _python_apply_general(self, f):
# --> 752         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     753
#     754         return self._wrap_applied_output(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     170         ):
#     171             try:
# --> 172                 result_values, mutated = splitter.fast_apply(f, group_keys)
#     173
#     174             except libreduction.InvalidApply as err:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in fast_apply(self, f, names)
#     928         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
#     929
# --> 930         sdata = self._get_sorted_data()
#     931         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#     932
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _get_sorted_data(self)
#     912
#     913     def _get_sorted_data(self) -> FrameOrSeries:
# --> 914         return self.data.take(self.sort_idx, axis=self.axis)
#     915
#     916     def _chop(self, sdata, slice_obj: slice) -> NDFrame:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3392         self._consolidate_inplace()
#    3393
# -> 3394         new_data = self._data.take(
#    3395             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3396         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1391
#    1392         new_labels = self.axes[axis].take(indexer)
# -> 1393         return self.reindex_indexer(
#    1394             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1395         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1257             new_blocks = self._slice_take_blocks_ax0(indexer, fill_tuple=(fill_value,))
#    1258         else:
# -> 1259             new_blocks = [
#    1260                 blk.take_nd(
#    1261                     indexer,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#    1258         else:
#    1259             new_blocks = [
# -> 1260                 blk.take_nd(
#    1261                     indexer,
#    1262                     axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1294             allow_fill = True
#    1295
# -> 1296         new_values = algos.take_nd(
#    1297             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1298         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1655             out = np.empty(out_shape, dtype=dtype, order="F")
#    1656         else:
# -> 1657             out = np.empty(out_shape, dtype=dtype)
#    1658
#    1659     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 572. MiB for an array with shape (15, 5000000) and data type object

# %%
Output1=[]
Output2=[]
Output3=[]

for i,j in group2:
    Output1.append(list( dict.fromkeys(j.values)))
    
for i,j in group4:
    Output2.append(j.values)
    
for i,j in group6:
    Output3.append(j.values)

# %%
indexes=[]
for a in Output1:
    if name in a:
        indexes.append(a)
    
#indexes

# %%
pds=[]
for i in range(len(indexes)):
    pds.append(pd.DataFrame(Output1[Output1.index(indexes[i])]))

# %%
vee = pd.concat(pds)

# %%
vout=[]
for i in range(len(indexes)):
    vout.append(pd.DataFrame(Output2[Output1.index(indexes[i])],columns= ['Color']))
    vout.append(pd.DataFrame(Output3[Output1.index(indexes[i])],columns= ['Color']))


veeO=pd.concat(vout)
dups_color = veeO.pivot_table(index=['Color'], aggfunc='size').sort_values(ascending=False)
dups_color

# %%
#name='pdaniel'
L=df.loc[df['User ID (v14) (evar14)'] == name]
L1=pd.DataFrame(L[['Header Item Clicked (v56) (evar56)']],columns= ['Header Item Clicked (v56) (evar56)'])
L2=pd.DataFrame(L[['Search Result Clicked Title (v23) (evar23)']],columns= ['Search Result Clicked Title (v23) (evar23)'])

Li1=L1.rename(columns={"Header Item Clicked (v56) (evar56)": "Color"})
Li2=L2.rename(columns={"Search Result Clicked Title (v23) (evar23)": "Color"})

vee=pd.concat([Li1 ,Li2])
dups_color2 = vee.pivot_table(index=['Color'], aggfunc='size').sort_values(ascending=False)

# %%
dups_color2

# %%
d1=pd.DataFrame(dups_color,columns= ['Count'])
d2=pd.DataFrame(dups_color2,columns= ['Count'])

# %%
pd.concat([d1,d2])
